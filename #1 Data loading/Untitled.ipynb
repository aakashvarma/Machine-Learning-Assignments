# %% [markdown]
# ### Pandas Tutorial

# %%
import csv
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt

# %%
f = open('diabetes.csv', 'r')
file = csv.reader(f, delimiter = ',')

# %%
x = list(file)
y = np.array(x)
y
# Out:
# array([['Pregnancies', 'Glucose', 'BloodPressure', ...,
#         'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#        ['6', '148', '72', ..., '0.627', '50', '1'],
#        ['1', '85', '66', ..., '0.351', '31', '0'],
#        ...,
#        ['5', '121', '72', ..., '0.245', '30', '0'],
#        ['1', '126', '60', ..., '0.349', '47', '1'],
#        ['1', '93', '70', ..., '0.315', '23', '0']], dtype='<U24')

# %%
df =pd.DataFrame(y)
df.columns = df.iloc[0]
df = df[1:]
df = df.apply(pd.to_numeric, downcast = 'float', errors='ignore')

# %%
df.head(10)
# Out:
# 0   Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 1           6.0    148.0           72.0           35.0      0.0  33.599998
# 2           1.0     85.0           66.0           29.0      0.0  26.600000
# 3           8.0    183.0           64.0            0.0      0.0  23.299999
# 4           1.0     89.0           66.0           23.0     94.0  28.100000
# 5           0.0    137.0           40.0           35.0    168.0  43.099998
# 6           5.0    116.0           74.0            0.0      0.0  25.600000
# 7           3.0     78.0           50.0           32.0     88.0  31.000000
# 8          10.0    115.0            0.0            0.0      0.0  35.299999
# 9           2.0    197.0           70.0           45.0    543.0  30.500000
# 10          8.0    125.0           96.0            0.0      0.0   0.000000
#
# 0   DiabetesPedigreeFunction   Age  Outcome
# 1                      0.627  50.0      1.0
# 2                      0.351  31.0      0.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=1, stop=769, step=1)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object', name=0)

# %%
df.dtypes
# Out:
# 0
# Pregnancies                 float32
# Glucose                     float32
# BloodPressure               float32
# SkinThickness               float32
# Insulin                     float32
# BMI                         float32
# DiabetesPedigreeFunction    float32
# Age                         float32
# Outcome                     float32
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
df.values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]],
#       dtype=float32)

# %%
df.sort_values(by = 'BMI').head()
# Out:
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 146          0.0    102.0           75.0           23.0      0.0  0.0
# 707         10.0    115.0            0.0            0.0      0.0  0.0
# 523          6.0    114.0            0.0            0.0      0.0  0.0
# 50           7.0    105.0            0.0            0.0      0.0  0.0
# 372          0.0    118.0           64.0           23.0     89.0  0.0
#
# 0    DiabetesPedigreeFunction   Age  Outcome
# 146                     0.572  21.0      0.0
# 707                     0.261  30.0      1.0
# 523                     0.189  26.0      0.0
# 50                      0.305  24.0      0.0
# 372                     1.731  21.0      0.0

# %%
df.describe()
# Out:
# 0      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536459   79.799477
# std       3.369578   31.972618      19.355808      15.952218  115.244003
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
# 0             BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992579                  0.471876   33.240887    0.348958
# std      7.884161                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### Selection by label

# %%
df['BMI'].head()
# Out:
# 1    33.599998
# 2    26.600000
# 3    23.299999
# 4    28.100000
# 5    43.099998
# Name: BMI, dtype: float32

# %%
df.loc[:,'Pregnancies'].head()
# Out:
# 1    6.0
# 2    1.0
# 3    8.0
# 4    1.0
# 5    0.0
# Name: Pregnancies, dtype: float32

# %%
df.loc[1:10, ('Pregnancies','BMI')]
# Out:
# 0   Pregnancies        BMI
# 1           6.0  33.599998
# 2           1.0  26.600000
# 3           8.0  23.299999
# 4           1.0  28.100000
# 5           0.0  43.099998
# 6           5.0  25.600000
# 7           3.0  31.000000
# 8          10.0  35.299999
# 9           2.0  30.500000
# 10          8.0   0.000000

# %% [markdown]
# ### Selection by position

# %%
df.iloc[0]
# Out:
# 0
# Pregnancies                   6.000000
# Glucose                     148.000000
# BloodPressure                72.000000
# SkinThickness                35.000000
# Insulin                       0.000000
# BMI                          33.599998
# DiabetesPedigreeFunction      0.627000
# Age                          50.000000
# Outcome                       1.000000
# Name: 1, dtype: float32

# %%
df.iloc[0,0]
# Out:
# 6.0

# %% [markdown]
# ### Boolean Indexing

# %%
df[df['BMI']>52]
# Out:
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 121          0.0    162.0           76.0           56.0    100.0  53.200001
# 126          1.0     88.0           30.0           42.0     99.0  55.000000
# 178          0.0    129.0          110.0           46.0    130.0  67.099998
# 194         11.0    135.0            0.0            0.0      0.0  52.299999
# 248          0.0    165.0           90.0           33.0    680.0  52.299999
# 304          5.0    115.0           98.0            0.0      0.0  52.900002
# 446          0.0    180.0           78.0           63.0     14.0  59.400002
# 674          3.0    123.0          100.0           35.0    240.0  57.299999
#
# 0    DiabetesPedigreeFunction   Age  Outcome
# 121                     0.759  25.0      1.0
# 126                     0.496  26.0      1.0
# 178                     0.319  26.0      1.0
# 194                     0.578  40.0      1.0
# 248                     0.427  23.0      0.0
# ...

# %% [markdown]
# #### Using the isin() method for filtering:

# %%
df2 = df.copy()
df2.E =['One', 'Two', 'Four', 'Two', 'One', 'One', 'Two']

# %%
df2[df2['E'].isin(['two','four'])]

# %% [markdown]
# ### Missing Data

# %%
df.dropna(how = 'any')
# Out:
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 1            6.0    148.0           72.0           35.0      0.0  33.599998
# 2            1.0     85.0           66.0           29.0      0.0  26.600000
# 3            8.0    183.0           64.0            0.0      0.0  23.299999
# 4            1.0     89.0           66.0           23.0     94.0  28.100000
# 5            0.0    137.0           40.0           35.0    168.0  43.099998
# 6            5.0    116.0           74.0            0.0      0.0  25.600000
# 7            3.0     78.0           50.0           32.0     88.0  31.000000
# 8           10.0    115.0            0.0            0.0      0.0  35.299999
# 9            2.0    197.0           70.0           45.0    543.0  30.500000
# 10           8.0    125.0           96.0            0.0      0.0   0.000000
# 11           4.0    110.0           92.0            0.0      0.0  37.599998
# ...

# %%
df.fillna(value = 5.0)
# Out:
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 1            6.0    148.0           72.0           35.0      0.0  33.599998
# 2            1.0     85.0           66.0           29.0      0.0  26.600000
# 3            8.0    183.0           64.0            0.0      0.0  23.299999
# 4            1.0     89.0           66.0           23.0     94.0  28.100000
# 5            0.0    137.0           40.0           35.0    168.0  43.099998
# 6            5.0    116.0           74.0            0.0      0.0  25.600000
# 7            3.0     78.0           50.0           32.0     88.0  31.000000
# 8           10.0    115.0            0.0            0.0      0.0  35.299999
# 9            2.0    197.0           70.0           45.0    543.0  30.500000
# 10           8.0    125.0           96.0            0.0      0.0   0.000000
# 11           4.0    110.0           92.0            0.0      0.0  37.599998
# ...

# %% [markdown]
# ### Operations

# %%
df.mean()
# Out:
# 0
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536459
# Insulin                      79.799477
# BMI                          31.992609
# DiabetesPedigreeFunction      0.471876
# Age                          33.240887
# Outcome                       0.348958
# dtype: float32

# %%
df.std()
# Out:
# 0
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355808
# SkinThickness                15.952218
# Insulin                     115.244003
# BMI                           7.884161
# DiabetesPedigreeFunction      0.331329
# Age                          11.760231
# Outcome                       0.476951
# dtype: float32

# %%
df.mean(1)
# Out:
# 1       38.469666
# 2       26.550112
# 3       34.663555
# 4       35.807446
# 5       51.043110
# 6       27.866777
# 7       34.360886
# 8       21.048222
# 9      104.628670
# 10      31.581333
# 11      30.421225
# 12      36.170776
# 13      34.949001
# 14     134.388672
# 15      57.265224
# 16      18.942667
# 17      61.927883
# 18      27.761557
# 19      36.831444
# 20      42.236557
# 21      62.222672
# 22      30.754221
# 23      41.694557
# 24      33.584778
# 25      57.317112
# 26      46.589443
# 27      34.850777
# 28      40.520779
# 29      49.827225
# 30      31.826334
#           ...
# 739     44.005890
# 740     28.865889
# 741     54.453892
# 742     35.577778
# 743     39.190998
# 744     35.826004
# 745     56.863777
# 746     45.609779
# 747     40.073109
# 748     37.043999
# 749     61.756443
# 750     33.942001
# 751     29.486887
# 752     42.251221
# 753     27.580332
# 754     99.280220
# 755     38.982559
# 756     49.061890
# 757     38.487888
# ...

# %% [markdown]
# ### Dataframe plotting

# %% [markdown]
# #### Historgams

# %%
df.hist()
plt.show()

# %% [markdown]
# #### Density plotting

# %%
df.plot(kind = 'density', subplots = True, layout = (3,3))
plt.show()
