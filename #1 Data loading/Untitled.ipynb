# %% [markdown]
# ### Practice

# %%
import csv
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt

# %%
f = open('diabetes.csv', 'r')
file = csv.reader(f, delimiter = ',')

# %%
x = list(file)
y = np.array(x)
y
# Out:
# array([['Pregnancies', 'Glucose', 'BloodPressure', ...,
#         'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#        ['6', '148', '72', ..., '0.627', '50', '1'],
#        ['1', '85', '66', ..., '0.351', '31', '0'],
#        ...,
#        ['5', '121', '72', ..., '0.245', '30', '0'],
#        ['1', '126', '60', ..., '0.349', '47', '1'],
#        ['1', '93', '70', ..., '0.315', '23', '0']], dtype='<U24')

# %%
df =pd.DataFrame(y)
df.columns = df.iloc[0]
df = df[1:]

# %%
df.head(10)
# Out:
# 0  Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 1            6     148            72            35       0  33.6
# 2            1      85            66            29       0  26.6
# 3            8     183            64             0       0  23.3
# 4            1      89            66            23      94  28.1
# 5            0     137            40            35     168  43.1
# 6            5     116            74             0       0  25.6
# 7            3      78            50            32      88    31
# 8           10     115             0             0       0  35.3
# 9            2     197            70            45     543  30.5
# 10           8     125            96             0       0     0
#
# 0  DiabetesPedigreeFunction Age Outcome
# 1                     0.627  50       1
# 2                     0.351  31       0
# 3                     0.672  32       1
# 4                     0.167  21       0
# 5                     2.288  33       1
# 6                     0.201  30       0
# 7                     0.248  26       1
# 8                     0.134  29       0
# 9                     0.158  53       1
# 10                    0.232  54       1

# %%
df.index
# Out:
# RangeIndex(start=1, stop=769, step=1)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object', name=0)

# %%
df.dtypes
# Out:
# 0
# Pregnancies                 object
# Glucose                     object
# BloodPressure               object
# SkinThickness               object
# Insulin                     object
# BMI                         object
# DiabetesPedigreeFunction    object
# Age                         object
# Outcome                     object
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
df.values
# Out:
# array([['6', '148', '72', ..., '0.627', '50', '1'],
#        ['1', '85', '66', ..., '0.351', '31', '0'],
#        ['8', '183', '64', ..., '0.672', '32', '1'],
#        ...,
#        ['5', '121', '72', ..., '0.245', '30', '0'],
#        ['1', '126', '60', ..., '0.349', '47', '1'],
#        ['1', '93', '70', ..., '0.315', '23', '0']], dtype=object)

# %%
df.sort_values(by = 'BMI')
# Out:
# 0   Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 146           0     102            75            23       0     0
# 707          10     115             0             0       0     0
# 523           6     114             0             0       0     0
# 50            7     105             0             0       0     0
# 372           0     118            64            23      89     0
# 685           5     136            82             0       0     0
# 61            2      84             0             0       0     0
# 10            8     125            96             0       0     0
# 427           0      94             0             0       0     0
# 82            2      74             0             0       0     0
# 495           3      80             0             0       0     0
# 419           1      83            68             0       0  18.2
# 439           1      97            70            15       0  18.2
# 527           1      97            64            19      82  18.2
# 240           0     104            76             0       0  18.4
# 91            1      80            55             0       0  19.1
# 317           3      99            80            11      64  19.3
# 51            1     103            80            11      82  19.4
# 640           1     100            74            12      46  19.5
# 608           1      92            62            25      41  19.5
# 520           6     129            90             7     326  19.6
# 69            1      95            66            13      38  19.6
# 454           2     119             0             0       0  19.6
# 34            6      92            92             0       0  19.9
# 382           0     105            68            22       0    20
# 618           2      68            62            13      15  20.1
# 204           2      99            70            16      44  20.4
# 98            1      71            48            18      76  20.4
# 461           9     120            72            22      56  20.8
# 289           4      96            56            17      49  20.8
# ..          ...     ...           ...           ...     ...   ...
# 329           2     102            86            36     120  45.5
# 288           1     119            86            39     220  45.6
# 271          10     101            86            37       0  45.6
# 392           5     166            76             0       0  45.7
# 17            0     118            84            47     230  45.8
# 470           6     154            78            41     140  46.1
# 690           1     144            82            46     180  46.1
# 232           6     134            80            37     370  46.2
# 559          11     103            68            40       0  46.2
# 748           1      81            74            41      57  46.3
# 488           0     173            78            32     265  46.5
# 93            7      81            78            40      48  46.7
# 58            0     100            88            60     110  46.8
# 591          11     111            84            40       0  46.8
# 155           8     188            78             0       0  47.9
# 336           0     165            76            43     255  47.9
# 379           4     156            75             0       0  48.3
# 85            5     137           108             0       0  48.8
# 747           1     147            94            41       0  49.3
# 682           0     162            76            36       0  49.6
# 100           1     122            90            51     220  49.7
# 156           7     152            88            44       0    50
# 248           0     165            90            33     680  52.3
# 194          11     135             0             0       0  52.3
# 304           5     115            98             0       0  52.9
# 121           0     162            76            56     100  53.2
# 126           1      88            30            42      99    55
# 674           3     123           100            35     240  57.3
# 446           0     180            78            63      14  59.4
# 178           0     129           110            46     130  67.1
#
# 0   DiabetesPedigreeFunction Age Outcome
# 146                    0.572  21       0
# 707                    0.261  30       1
# 523                    0.189  26       0
# 50                     0.305  24       0
# 372                    1.731  21       0
# 685                     0.64  69       0
# 61                     0.304  21       0
# 10                     0.232  54       1
# 427                    0.256  25       0
# 82                     0.102  22       0
# 495                    0.174  22       0
# 419                    0.624  27       0
# 439                    0.147  21       0
# 527                    0.299  21       0
# 240                    0.582  27       0
# 91                     0.258  21       0
# 317                    0.284  30       0
# 51                     0.491  22       0
# 640                    0.149  28       0
# 608                    0.482  25       0
# 520                    0.582  60       0
# 69                     0.334  25       0
# 454                    0.832  72       0
# 34                     0.188  28       0
# 382                    0.236  22       0
# 618                    0.257  23       0
# 204                    0.235  27       0
# 98                     0.323  22       0
# 461                    0.733  48       0
# 289                     0.34  26       0
# ..                       ...  ..     ...
# 329                    0.127  23       1
# 288                    0.808  29       1
# 271                    1.136  38       1
# 392                     0.34  27       1
# 17                     0.551  31       1
# 470                    0.571  27       0
# 690                    0.335  46       1
# 232                    0.238  46       1
# 559                    0.126  42       0
# 748                    1.096  32       0
# 488                    1.159  58       0
# 93                     0.261  42       0
# 58                     0.962  31       0
# 591                    0.925  45       1
# 155                    0.137  43       1
# 336                    0.259  26       0
# 379                    0.238  32       1
# 85                     0.227  37       1
# 747                    0.358  27       1
# 682                    0.364  26       1
# 100                    0.325  31       1
# 156                    0.337  36       1
# 248                    0.427  23       0
# 194                    0.578  40       1
# 304                    0.209  28       1
# 121                    0.759  25       1
# 126                    0.496  26       1
# 674                     0.88  22       0
# 446                     2.42  25       1
# 178                    0.319  26       1
#
# [768 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: (1, 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-3804243272c7> in <module>()
# ----> 1 df[1,0]
#
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: (1, 0)
