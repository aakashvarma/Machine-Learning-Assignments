# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Basics

# %%
plt.plot(x, y, 'b')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.ylim([0, 40])
plt.xlim([0, 10])
plt.title('Graph Title')
plt.show()

# %% [markdown]
# ### Subplotting

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.title('First Plot')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'b*-')
plt.title('Second Plot')
plt.show()

# %% [markdown]
# ## Matplotlib Object Oriented Method

# %%
fig = plt.figure() #Create Figure (empty )

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #left. bottom, width, height (range 0 to 1)

axes.plot(x, y, c = 'b')
axes.set_xlabel('Set X Label')
axes.set_ylabel('Set Y Label')
axes.set_title("Set Title")
# Out:
# Text(0.5,1,'Set Title')

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ### Subplots()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

# %%
for ax in axes:
    ax.plot(x, y, 'b')

fig

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)
for ax in axes:
    ax.plot(x, y, 'b')
fig
plt.tight_layout()

# %%
fig, axes = plt.subplots(figsize=(8,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# ##### To save a figure to a file we can use the savefig method in the Figure class:

# %%
fig.savefig("filename.png", dpi=200)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x+2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**4, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# ## Histograms in matplotlib

# %%
N_points = 100000
n_bins = 20

x = np.random.randn(N_points)
y = .4 * x +np.random.randn(N_points) + 5

y
# Out:
# array([4.2220723 , 4.67386571, 4.9503731 , ..., 3.04750623, 4.51482148,
#        3.81592026])

# %%
fig, axes = plt.subplots(1, 2, tight_layout = True)

axes[0].hist(x, bins = n_bins)
axes[1].hist(y, bins = n_bins)

from matplotlib.ticker import PercentFormatter

axes[1].yaxis.set_major_formatter(PercentFormatter(xmax=1))

plt.show()
# Out:
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y)
# Out:
# c:\users\aakash\appdata\local\programs\python\python35\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Scatter Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, c = 'r', s=area, alpha=0.5, marker = '+')
plt.show()
